# %% [markdown]
# # CA III - Introduction to Data Science - BCA DS III
# ## 2020-B-13092002A
# ## Sumit Pandey

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import missingno

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_csv('car_data3.csv')
df.head(10)
# Out:
#                         name    year  selling_price  km_driven    fuel  \
# 0              Maruti 800 AC  2007.0        60000.0    70000.0  Petrol
# 1   Maruti Wagon R LXI Minor  2007.0       135000.0    50000.0  Petrol
# 2       Hyundai Verna 1.6 SX  2012.0       600000.0   100000.0  Diesel
# 3     Datsun RediGO T Option  2017.0       250000.0    46000.0  Petrol
# 4      Honda Amaze VX i-DTEC  2014.0       450000.0   141000.0  Diesel
# 5       Maruti Alto LX BSIII  2007.0       140000.0   125000.0  Petrol
# 6  Hyundai Xcent 1.2 Kappa S     NaN       550000.0    25000.0  Petrol
# 7   Tata Indigo Grand Petrol     NaN       240000.0    60000.0  Petrol
# 8   Hyundai Creta 1.6 VTVT S     NaN       850000.0    25000.0  Petrol
# 9   Maruti Celerio Green VXI     NaN       365000.0    78000.0     CNG
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# ...

# %% [markdown]
# - Original data is seperated by delimiter " ; " in given dataset
# - " .head() " returns first five observations of the dataset
# - “ .tail() ” returns last five observations of the data set
#
# - Now we will find out the total number of rows and columns in the data set using “.shape”.

# %% [markdown]
# # Data Insights

# %%
df.shape
# Out:
# (4340, 8)

# %% [markdown]
# - dataset comprises of 4340 observations and 8 chracteriestics

# %%
df.columns.values
# Out:
# array(['name', 'year', 'selling_price', 'km_driven', 'fuel',
#        'seller_type', 'transmission', 'owner'], dtype=object)

# %% [markdown]
# - Label of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4304 non-null   float64
#  2   selling_price  4295 non-null   float64
#  3   km_driven      4309 non-null   float64
#  4   fuel           4256 non-null   object
#  5   seller_type    1720 non-null   object
#  6   transmission   4176 non-null   object
#  7   owner          2995 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 271.4+ KB

# %% [markdown]
# - Data has only float and integer values
# - No variable column has null/missing values

# %% [markdown]
# # Summary Statistics

# %%
df.isnull()
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 4335  False  False          False      False  False         True
# 4336  False  False          False      False  False         True
# 4337  False  False          False      False  False         True
# 4338  False  False          False      False  False         True
# 4339  False  False          False      False  False         True
#
#       transmission  owner
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4304.000000   4.295000e+03    4309.000000
# mean   2013.079926   5.046909e+05   66165.159898
# std       4.222669   5.799389e+05   46681.663263
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.100000e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
#checking null values in %
df.isnull().mean() * 100
# Out:
# name              0.000000
# year              0.829493
# selling_price     1.036866
# km_driven         0.714286
# fuel              1.935484
# seller_type      60.368664
# transmission      3.778802
# owner            30.990783
# dtype: float64

# %% [markdown]
# # Understanding Target variable

# %%
df.selling_price.value_counts()
# Out:
# 300000.0     162
# 250000.0     122
# 350000.0     120
# 550000.0     107
# 450000.0     100
#             ...
# 324000.0       1
# 2100000.0      1
# 828999.0       1
# 1119000.0      1
# 865000.0       1
# Name: selling_price, Length: 445, dtype: int64

# %% [markdown]
# - This tells us vote count of each selling_price score in descending order.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # To check missing values

# %%
# Plot graphic of missing values
missingno.matrix(df, figsize = (40,20))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Dataset no missing values.
# - Above and this graphic convey the same message.
# - Ex: In Titanic dataset,you will find "Age" and "Cabin" columns with differnt shades with this code.

# %%
# Plot graphic of missing values
missingno.bar(df, figsize = (30,10))
# Out:
# <AxesSubplot:>

# %%
df["fuel"].value_counts()
# Out:
# Diesel      2111
# Petrol      2082
# CNG           40
# LPG           22
# Electric       1
# Name: fuel, dtype: int64

# %%
sns.countplot(x=df["fuel"],data=df)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %%
sns.countplot(x=df["selling_price"],data=df)
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='count'>

# %%
#create a countplot for fuel column w.r.t.transmission
sns.countplot(x=df["fuel"],data=df,hue=df["transmission"])
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#for a numeric column, replace null values with its mean value
df["selling_price"].mean()
# Out:
# 504690.9282887078

# %%
# nan / null values
df.isnull().sum()
# Out:
# name                0
# year               36
# selling_price      45
# km_driven          31
# fuel               84
# seller_type      2620
# transmission      164
# owner            1345
# dtype: int64

# %% [markdown]
# # Bivariate analysis

# %%
sns.countplot(x=df["fuel"],data=df, hue=df["km_driven"])
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %% [markdown]
# # Variable Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lbl=LabelEncoder()

# %%
df["seller_type"]=lbl.fit_transform(df["seller_type"])

# %%
df["seller_type"].value_counts()
# Out:
# 3    2620
# 1    1302
# 0     355
# 2      63
# Name: seller_type, dtype: int64

# %%
#one-hot encoding 
pd.get_dummies(df["seller_type"])
pd.get_dummies(df["seller_type"],drop_first=True)
# Out:
#       1  2  3
# 0     1  0  0
# 1     1  0  0
# 2     1  0  0
# 3     1  0  0
# 4     1  0  0
# ...  .. .. ..
# 4335  0  0  1
# 4336  0  0  1
# 4337  0  0  1
# 4338  0  0  1
# 4339  0  0  1
#
# [4340 rows x 3 columns]

# %%
pd.get_dummies(df["transmission"],drop_first=True)
# Out:
#       Manual
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 4335       1
# 4336       1
# 4337       1
# 4338       1
# 4339       1
#
# [4340 rows x 1 columns]

# %% [markdown]
# # To check correlation

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),cmap='Blues',annot=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Dark shades represents positive correlation while lighter shades represents negative correlation.
# - If you set annot=True, you'll get values by which features are correlated to each other in grid-cells

# %%
#Quality correlation matrix
k = 12 #number of variables for heatmap
cols = df.corr().nlargest(k, 'selling_price')['selling_price'].index
cm = df[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')
# Out:
# <AxesSubplot:>
